# %%
# Naman Bothra
# prn - 25070123078
# Experiment 2 - Study of list in python

list1 = ["apple", "banana", "cherry"]
print(list1)
# Out:
# ['apple', 'banana', 'cherry']

# %%
list2 = [2,2.5,"orange",True]
print(list2)
# Out:
# [2, 2.5, 'orange', True]

# %%
list3 = ["apple","orange","apple","cherry"]
print(list3)
# Out:
# ['apple', 'orange', 'apple', 'cherry']

# %%
list4 = ["apple","banana","orange","cherry","mango","kiwi"]
print(list4[0])
print(list4[1])
print(list4[2])
print(list4[3])
print(list4[4])
print(list4[5])

print(list4[-1])
print(list4[-2])
print(list4[-3])
print(list4[-4])
print(list4[-5])
print(list4[-6])
# Out:
# apple
# banana
# orange
# cherry
# mango
# kiwi
# kiwi
# mango
# cherry
# orange
# banana
# apple

# %%
list4 = ["apple","banana","orange","cherry","mango","kiwi"]
print(list4[2:5])
print(list4[:4])
print(list4[2:])
# Out:
# ['orange', 'cherry', 'mango']
# ['apple', 'banana', 'orange', 'cherry']
# ['orange', 'cherry', 'mango', 'kiwi']

# %%
list5 = ["apple","orange","mango"]
list5[1]=2
print(list5)
# Out:
# ['apple', 2, 'mango']

# %%
list6 = ["apple","orange","cherry"]
list6.append("mango")
print(list6)
# Out:
# ['apple', 'orange', 'cherry', 'mango']

# %%
list7 = ["apple","orange","cherry"]
list7.insert(1,"mango")
print(list7)
# Out:
# ['apple', 'mango', 'orange', 'cherry']

# %%
list8 = ["apple","orange","banana"]
list9 = ["kiwi","mango"]
list8.extend(list9)
print(list8)
print(list9)
# Out:
# ['apple', 'orange', 'banana', 'kiwi', 'mango']
# ['kiwi', 'mango']

# %%
marks = [90,82,66,76,33]
print(max(marks))
print(min(marks))
print(sum(marks))
print(len(marks))
print(sum(marks)/len(marks))
print(sorted(marks))
marks.sort()
print(marks)

# %%
Grocery = ["apple","orange","mango","banana","kiwi"]
Grocery.append("bread")
print(Grocery)
Grocery.remove("bread")
Grocery.remove("apple")
print(Grocery)
# Out:
# ['apple', 'orange', 'mango', 'banana', 'kiwi', 'bread']
# ['orange', 'mango', 'banana', 'kiwi']
